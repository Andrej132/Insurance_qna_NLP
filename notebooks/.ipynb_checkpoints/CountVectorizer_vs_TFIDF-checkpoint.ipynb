# %%
import pandas as pd
import re
import numpy
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from gensim.models import Word2Vec

#nltk.download("punkt")
#nltk.download("wordnet")
#nltk.download("stopwords")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 8
#       6 from nltk.stem import PorterStemmer, WordNetLemmatizer
#       7 from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
# ----> 8 from gensim.models import Word2Vec
#      10 #nltk.download("punkt")
#      11 #nltk.download("wordnet")
#      12 #nltk.download("stopwords")
#
# File ~\Desktop\Insurance_qna_NLP\.venv\Lib\site-packages\gensim\__init__.py:11
#       7 __version__ = '4.3.3'
#       9 import logging
# ---> 11 from gensim import parsing, corpora, matutils, interfaces, models, similarities, utils  # noqa:F401
#      14 logger = logging.getLogger('gensim')
#      15 if not logger.handlers:  # To ensure reload() doesn't add another one
#
# File ~\Desktop\Insurance_qna_NLP\.venv\Lib\site-packages\gensim\corpora\__init__.py:6
#       1 """
# ...

# %%
df = pd.read_csv('../data/insurance_qna_dataset.csv', delimiter='\t')
df = df.dropna(subset=['Question', 'Answer'])
df
# Out:
#        Unnamed: 0                                           Question  \
# 0               0  What Happens When Term Life Insurance Is Paid ...
# 1               1  What Happens When Term Life Insurance Is Paid ...
# 2               2  What Happens When Term Life Insurance Is Paid ...
# 3               3                What Does Renters Insurance Cover?
# 4               4                What Does Renters Insurance Cover?
# ...           ...                                                ...
# 27989       27989                                           What is
# 27990       27990                                             Can I
# 27991       27991                                             Which
# 27992       27992                                              Does
# 27993       27993                                                Is
#
#                                                   Answer
# 0      Actually term life insurance cannot be paid up...
# ...

# %%
stop_words = set(stopwords.words("english"))
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

def preprocess(text, lower=True, remove_stopwords=False, stem=False, lemm=False):
    if lower:
        text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    tokens = nltk.word_tokenize(text)
    if remove_stopwords:
        tokens = [t for t in tokens if t not in stop_words]
    if stem:
        tokens = [stemmer.stem(t) for t in tokens]
    if lemm:
        tokens = [lemmatizer.lemmatize(t) for t in tokens]
    return ' '.join(tokens)

# %%
df["Question_stem"] = df["Question"].apply(
    lambda x: preprocess(x, lower=True, remove_stopwords=True, stem=True, lemm=False)
)
df["Question_lemm"] = df["Question"].apply(
    lambda x: preprocess(x, lower=True, remove_stopwords=True, stem=False, lemm=True)
)
df.head()
# Out:
#    Unnamed: 0                                           Question  \
# 0           0  What Happens When Term Life Insurance Is Paid ...
# 1           1  What Happens When Term Life Insurance Is Paid ...
# 2           2  What Happens When Term Life Insurance Is Paid ...
# 3           3                What Does Renters Insurance Cover?
# 4           4                What Does Renters Insurance Cover?
#
#                                               Answer  \
# 0  Actually term life insurance cannot be paid up...
# 1  Term life insurance is never paid up. Assuming...
# 2  Term Life Insurance does not have the option t...
# 3  A renters insurance policy will typically prov...
# 4  If you apartment was on fire and all your pers...
#
#                  Question_stem                     Question_lemm
# 0  happen term life insur paid  happens term life insurance paid
# 1  happen term life insur paid  happens term life insurance paid
# ...
